# %% [markdown]
# # LOAD THE DATASET FROM THE GIVEN BELOW LINK.

# %% [markdown]
# https://drive.google.com/file/d/1RWvyhf9AcDZsSB5xVVgzsbHI1m4sFBJf/view?usp=share_link

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ahire\Downloads\chipotle.tsv",sep='\t',index_col=0,header=0)
df['item_price']=df['item_price'].str[1:].astype(float)
df['price per item']=df['item_price']/df['quantity']
df
# Out:
#           quantity                              item_name  \
# order_id
# 1                1           Chips and Fresh Tomato Salsa
# 1                1                                   Izze
# 1                1                       Nantucket Nectar
# 1                1  Chips and Tomatillo-Green Chili Salsa
# 2                2                           Chicken Bowl
# ...            ...                                    ...
# 1833             1                          Steak Burrito
# 1833             1                          Steak Burrito
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
# 1834             1                     Chicken Salad Bowl
#
#                                          choice_description  item_price  \
# order_id
# 1                                                       NaN        2.39
# 1                                              [Clementine]        3.39
# ...

# %% [markdown]
# # USING PANDAS FUNCTION CALCULATE HOW MANY PRODUCTS COSTS MORE THAN $10?

# %%
cost_10=df[df['price per item']>10].count().max()
print('There are ', cost_10,' products costs more than $10')
# Out:
# There are  1034  products costs more than $10

# %% [markdown]
# # What is the price of each item?

# %%
x=df.loc[1:,['item_name','price per item']]
x.drop_duplicates(subset='item_name',keep='first')
# Out:
#                                       item_name  price per item
# order_id
# 1                  Chips and Fresh Tomato Salsa            2.39
# 1                                          Izze            3.39
# 1                              Nantucket Nectar            3.39
# 1         Chips and Tomatillo-Green Chili Salsa            2.39
# 2                                  Chicken Bowl            8.49
# 3                                 Side of Chips            1.69
# 4                                 Steak Burrito           11.75
# 4                              Steak Soft Tacos            9.25
# 5                           Chips and Guacamole            4.45
# 6                          Chicken Crispy Tacos            8.75
# 6                            Chicken Soft Tacos            8.75
# 8                               Chicken Burrito            8.49
# 9                                   Canned Soda            1.09
# ...

# %% [markdown]
# # Which is the Most Expensive Item?

# %%
df.nlargest(1,columns=['item_price'],keep='first')
# Out:
#           quantity                     item_name choice_description  \
# order_id
# 1443            15  Chips and Fresh Tomato Salsa                NaN
#
#           item_price
# order_id
# 1443           44.25
